# %%
import numpy as np
import pandas as pd
from numpy.random import randn

np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4), ["A","B", "C", "D", "E"], ["W", "X", "Y", "Z"])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df > 0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df["W"] > 0
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: W, dtype: bool

# %%
df[df["W"] > 0][["X", "W"]]
# Out:
#           X         W
# A  0.628133  2.706850
# B -0.319318  0.651118
# D -0.758872  0.188695
# E  1.978757  0.190794

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[(df["W"] > 0) & (df["Y"]<1)]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df[(df["Z"]>1) | (df["Y"]>1)]
# Out:
#           W         X         Y         Z
# E  0.190794  1.978757  2.605967  0.683509

# %%
new_df = df.reset_index()

# %%
new_df
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
new_df.drop("index", axis=1)
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509

# %%
new_df
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
new_ind = "AC NY CO LA OS".split()
new_df["state"] = new_ind

# %%
new_df
# Out:
#   index         W         X         Y         Z state
# 0     A  2.706850  0.628133  0.907969  0.503826    AC
# 1     B  0.651118 -0.319318 -0.848077  0.605965    NY
# 2     C -2.018168  0.740122  0.528813 -0.589001    CO
# 3     D  0.188695 -0.758872 -0.933237  0.955057    LA
# 4     E  0.190794  1.978757  2.605967  0.683509    OS

# %%
new_df.shape
# Out:
# (5, 6)

# %%
new_df.set_index("state", inplace=True)

# %%
new_df
# Out:
#       index         W         X         Y         Z
# state
# AC        A  2.706850  0.628133  0.907969  0.503826
# NY        B  0.651118 -0.319318 -0.848077  0.605965
# CO        C -2.018168  0.740122  0.528813 -0.589001
# LA        D  0.188695 -0.758872 -0.933237  0.955057
# OS        E  0.190794  1.978757  2.605967  0.683509

# %%
new_df.shape
# Out:
# (5, 5)
